# %% [markdown]
# # Figure 4/S4: mRNA compositional relationship arises from transcription-translation balance

# %%
import numpy as np
import pandas as pd

import sys
sys.path.insert(0, '../analysis')
from model1 import run_model, plot_log2fc_heatmap
from bayesian_model1_ecoli import fit_model, predict_from_trace, \
    plot_protein_fractions, plot_mrna_fractions
from load_ecoli_fractions import label_genes, compute_fractions, REMOVE_MRNA, REMOVE_PROTEIN
from load_spombe_fractions import load_annotations, compute_mrna_fractions, compute_protein_fractions
from bayesian_model1_spombe import (fit_model_spombe, predict_from_trace_spombe,
                                     plot_protein_fractions_spombe, plot_mrna_fractions_spombe)

import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

import holoviews as hv
hv.extension('bokeh')

import arviz as az
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bd40ff16-f8ea-4d7c-9b5e-23ad29998f36">Loading BokehJS ...</span>
#     </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='59dff498-dda6-46f1-81a3-26f64adc19fc'>
#   <div id="f85c9c68-28e0-40ef-8276-3ecfe1e47299" data-root-id="59dff498-dda6-46f1-81a3-26f64adc19fc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5b1f8696-3e48-4453-87cd-8d8f1b36c96f":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"59dff498-dda6-46f1-81a3-26f64adc19fc"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"4e32f52f-8300-4d3f-9000-fb5f370bd900","attributes":{"plot_id":"59dff498-dda6-46f1-81a3-26f64adc19fc","comm_id":"9b2349bcb0ce4a82a011a1e0287c81d9","client_comm_id":"b2fcaae615b1433b9dfb7ea94e1b888d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"5b1f8696-3e48-4453-87cd-8d8f1b36c96f","roots":{"59dff498-dda6-46f1-81a3-26f64adc19fc":"f85c9c68-28e0-40ef-8276-3ecfe1e47299"},"root_ids":["59dff498-dda6-46f1-81a3-26f64adc19fc"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# ## Figure 4B: Hierarchical clustering remake

# %% [raw]
# # Params used:
#
# growths = np.linspace(0.05,0.3,200)
#
# d_mrna = 0.225
# d_mrna_r = 0.098
# d_mrna_c = 0.243
# d_mrna_q = 0.569
#
# gamma_1 = 3.42
# gamma_2 = 0.005
# alpha_q0 = 0.858
# #alpha_q = 0.05
# Km = 0.0001

# %%
results = run_model()
heatmap = plot_log2fc_heatmap(results)
heatmap
# Out:
# :HeatMap   [Growth rate,mRNA species]   (log2FC)

# %% [markdown]
# ## Figure 4C/S4A: Model 1 fit to E. coli data

# %% [markdown]
# **Load mRNA, protein, and growth data**

# %%
df_mrna_data   = pd.read_excel('../data/e.coli/science.abk2066_table_s3.xlsx', sheet_name=1)
df_mrna_growth = pd.read_excel('../data/e.coli/science.abk2066_table_s3.xlsx', sheet_name=0)

df_prot_data   = pd.read_excel('../data/e.coli/science.abk2066_table_s4.xlsx', sheet_name=1)
df_prot_growth = pd.read_excel('../data/e.coli/science.abk2066_table_s4.xlsx', sheet_name=0)

# %% [markdown]
# **Load E. coli annotation file**

# %%
df_ann = pd.read_csv('../data/e.coli/Schmidt2016_proteomics.csv')

# %% [markdown]
# **Define mRNA and protein fractions**

# %%
gene_to_label = label_genes(df_ann)


mrna_fracs = compute_fractions(df_mrna_data, df_mrna_growth, gene_to_label,
                               remove_samples=REMOVE_MRNA)


prot_fracs = compute_fractions(df_prot_data, df_prot_growth, gene_to_label,
                               remove_samples=REMOVE_PROTEIN)

# Define arrays for Bayesian fitting
mrna_growth = mrna_fracs['Growth rate'].values
mrna_r_frac = mrna_fracs['R'].values
mrna_c_frac = mrna_fracs['C'].values
mrna_q_frac = mrna_fracs['O'].values

protein_growth = prot_fracs['Growth rate'].values
R_P_frac = prot_fracs['R'].values
C_P_frac = prot_fracs['C'].values
Q_P_frac = prot_fracs['O'].values

# %% [markdown]
# **Fit to bayesian model and output plots with data overlayed**

# %%
trace = fit_model(protein_growth, R_P_frac, Q_P_frac, C_P_frac,
                  mrna_growth, mrna_r_frac, mrna_c_frac, mrna_q_frac)

preds  = predict_from_trace(trace, protein_growth, mrna_growth)
p_prot = plot_protein_fractions(protein_growth, R_P_frac, C_P_frac, Q_P_frac, preds)
p_mrna = plot_mrna_fractions(mrna_growth, mrna_r_frac, mrna_c_frac, mrna_q_frac, preds)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:07
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 3_000 tune and 3_000 draw iterations (12_000 + 12_000 draws total) took 8 seconds.
#   <div id="cf478f46-595a-4670-9611-66cf203ff56c" data-root-id="ed646865-b094-45e1-8726-e43243645918" style="display: contents;"></div>
#   <div id="e812a28f-3a9a-4f28-a213-ba5367563864" data-root-id="9f1604d5-8684-4573-9fbd-c4224f398a76" style="display: contents;"></div>

# %%
az.summary(trace)
# Out:
#                 mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# gamma_1        2.364  0.090   2.196    2.528      0.001    0.001    7497.0
# alpha_q0       0.451  0.010   0.432    0.469      0.000    0.000    9004.0
# sigma_d        0.332  0.134   0.128    0.588      0.002    0.002    6702.0
# d_mrna_r       0.803  0.179   0.501    1.126      0.003    0.008    3949.0
# d_mrna_c       1.432  0.332   0.889    2.018      0.006    0.017    3770.0
# d_mrna_q       0.931  0.206   0.580    1.295      0.004    0.011    3753.0
# sigma_protein  0.046  0.005   0.037    0.056      0.000    0.000    7675.0
# sigma_mrna     0.057  0.006   0.045    0.069      0.000    0.000    9998.0
# dmrna/gamma_2  4.536  2.456   0.989    8.720      0.025    0.044   10081.0
#
#                ess_tail  r_hat
# gamma_1          6562.0    1.0
# alpha_q0         7243.0    1.0
# sigma_d          6462.0    1.0
# d_mrna_r         4037.0    1.0
# d_mrna_c         4148.0    1.0
# d_mrna_q         3743.0    1.0
# sigma_protein    6903.0    1.0
# sigma_mrna       8242.0    1.0
# dmrna/gamma_2    7919.0    1.0

# %% [markdown]
# ## Figure 4D/S4B: Model 1 fit to S. pombe data

# %% [markdown]
# **Load annotation files**

# %%
# Load annotations
ribo_ids, mito_ids = load_annotations(
    '../analysis/s.pombe_annotations/structuralConstituentofRibosome_pombase.tsv',
    '../analysis/s.pombe_annotations/mitophagy_pombase.tsv'
)

# %% [markdown]
# **Load mRNA and protein data and compute fractions**

# %%
# Compute fractions
mrna_fracs = compute_mrna_fractions(
    '../data/s.pombe/normalized_mRNA_counts.xlsx',
    '../data/s.pombe/growth_info.xlsx',
    ribo_ids, mito_ids
)

prot_fracs = compute_protein_fractions(
    '../data/s.pombe/proteomics_analysis_istvan.xlsx',
    '../data/s.pombe/growth_info.xlsx',
    ribo_ids, mito_ids
)

# Define arrays
mrna_growth  = mrna_fracs['Growth rate'].values
mrna_r_frac  = mrna_fracs['R'].values
mrna_m_frac  = mrna_fracs['M'].values
mrna_q_frac  = mrna_fracs['Q'].values

protein_growth = prot_fracs['Growth rate'].values
R_P_frac = prot_fracs['R'].values
M_P_frac = prot_fracs['M'].values
Q_P_frac = prot_fracs['Q'].values

# %% [markdown]
# **Fit to bayesian model and output plots with data overlayed**

# %%
trace  = fit_model_spombe(protein_growth, R_P_frac, M_P_frac, Q_P_frac,
                           mrna_growth, mrna_r_frac, mrna_m_frac, mrna_q_frac)
preds  = predict_from_trace_spombe(trace, protein_growth, mrna_growth)
p_prot = plot_protein_fractions_spombe(protein_growth, R_P_frac, M_P_frac, Q_P_frac, preds)
p_mrna = plot_mrna_fractions_spombe(mrna_growth, mrna_r_frac, mrna_m_frac, mrna_q_frac, preds)
az.summary(trace)
# Out:
# Sampling 4 chains, 18,319 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:41
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 8_000 tune and 6_000 draw iterations (32_000 + 24_000 draws total) took 42 seconds.
# There were 18319 divergences after tuning. Increase `target_accept` or reparameterize.
#   <div id="aae2d2d4-b661-4a87-b835-50b4113f908d" data-root-id="1a936f3d-7077-45ed-bf10-46822f681053" style="display: contents;"></div>
#   <div id="e61e7d0a-0a28-425d-b839-95de83f2464a" data-root-id="04c5a351-ce53-4c15-9910-75a94fc6d1e2" style="display: contents;"></div>
#                  mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# gamma_1         3.230  0.145   2.959    3.502      0.003    0.002    1946.0
# alpha_q0        0.900  0.011   0.879    0.916      0.000    0.000    1819.0
# sigma_d         0.933  0.154   0.658    1.223      0.003    0.002    3110.0
# d_mrna_c       14.484  6.035   6.368   24.518      0.113    0.136    2242.0
# d_mrna_q        4.289  0.277   3.768    4.806      0.006    0.004    1902.0
# sigma_protein   0.012  0.002   0.009    0.015      0.000    0.000    4022.0
# sigma_mrna      0.038  0.003   0.032    0.044      0.000    0.000    3706.0
# dmrna/gamma_2   4.530  2.410   1.083    8.835      0.039    0.048    4077.0
#
#                ess_tail  r_hat
# gamma_1          2234.0   1.00
# alpha_q0         1936.0   1.01
# sigma_d          3591.0   1.00
# d_mrna_c         2789.0   1.00
# d_mrna_q         2461.0   1.00
# sigma_protein    5258.0   1.00
# sigma_mrna       4307.0   1.00
# dmrna/gamma_2    5461.0   1.00

# %%
# %load_ext watermark
# %watermark -v -p numpy,pandas,sys,bokeh,arviz,pymc
# Out:
# Python implementation: CPython
# Python version       : 3.12.8
# IPython version      : 8.30.0
#
# numpy : 1.26.4
# pandas: 2.2.3
# sys   : 3.12.8 | packaged by conda-forge | (main, Dec  5 2024, 14:19:53) [Clang 18.1.8 ]
# bokeh : 3.7.3
# arviz : 0.21.0
# pymc  : 5.19.1
