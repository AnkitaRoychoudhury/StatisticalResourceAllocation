# %% [markdown]
# ## Figure 5/S5: Model 2 — nutrient-dependent regimes
#
# Total mRNA, ribosome fraction, and elongation rate vs growth rate
# for three regimes: **co-limitation** (E. coli), **ribosomal mRNA limitation** (S. cerevisiae), and **tRNA limitation**.

# %%
import numpy as np
import sys
sys.path.insert(0, '../analysis')

import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

from model2 import (
    DEFAULT_ECOLI, DEFAULT_YEAST, DEFAULT_TRNA, DEFAULT_SHARED,
    solve_steady_state,
    plot_total_mrna, plot_ribosome_fraction, plot_elongation_rate,
)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f3e8f9d8-39d9-4a60-8661-29bbfe9ed658">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Figure 5C/S5B: Example model outputs of various regimes

# %% [markdown]
# **Define parameters**

# %%
#  Co-limitation regime (E. coli)
ecoli_params = dict(
    alpha = 95,    # max translation rate
    beta  = 2,     # amino-acid production per metabolic protein
    eta   = 1,     # AA cost per ribosome cycle
    kappa = 10,    # metabolic capacity scalar
    delta = 130,   # tRNA decay rate
)

#  Ribosomal mRNA limitation regime (S. cerevisiae)
yeast_params = dict(
    alpha = 2,
    beta  = 3000,
    eta   = 0.3,
    kappa = 0.01,
    delta = 130,
)

#  tRNA limitation regime 
trna_params = dict(
    alpha = 95,
    beta  = 0.01,
    eta   = 0.1,
    kappa = 10,
    delta = 10,
)

#  Shared transcription parameters 
shared_params = dict(
    alpha_c    = 0.05,
    alpha_r    = 0.9,
    alpha_pol2 = 0.05,
    mq         = 1.0,
)

#  Growth rate ranges 
ecoli_growth     = np.linspace(0.002, 0.9, 70)
yeast_growth     = np.linspace(0.02,  0.7, 40)
yeast_growth_min = 0.1
trna_growth      = np.linspace(2, 5, 70)

# %% [markdown]
# ### Solve steady states

# %%
ecoli_data = solve_steady_state(ecoli_params, shared_params, ecoli_growth)
yeast_data = solve_steady_state(yeast_params, shared_params, yeast_growth,
                                growth_min=yeast_growth_min)
trna_data  = solve_steady_state(trna_params,  shared_params, trna_growth)

# %% [markdown]
# ### Total mRNA fold change

# %%
p1, p2, p3 = plot_total_mrna(ecoli_data, yeast_data, trna_data)
bokeh.io.show(p1)
bokeh.io.show(p2)
bokeh.io.show(p3)
# Out:
#   <div id="ea054727-6e04-437e-a82b-624a276d45ff" data-root-id="p1008" style="display: contents;"></div>
#   <div id="fbe56e46-367f-43d7-aec4-b73ce339c03b" data-root-id="p1053" style="display: contents;"></div>
#   <div id="eade5cae-3a4a-4638-b699-d6ef6a973e64" data-root-id="p1098" style="display: contents;"></div>

# %% [markdown]
# ### Ribosome fraction

# %%
p4, p5, p6 = plot_ribosome_fraction(ecoli_data, yeast_data, trna_data)
bokeh.io.show(p4)
bokeh.io.show(p5)
bokeh.io.show(p6)
# Out:
#   <div id="ea86ce84-9f3d-46a4-afb7-c74d1b628d41" data-root-id="p1155" style="display: contents;"></div>
#   <div id="d4616ecf-8c7a-42df-8295-52bbba1927a2" data-root-id="p1200" style="display: contents;"></div>
#   <div id="d720e77b-295e-4d80-a7e5-b0fc0a97310e" data-root-id="p1245" style="display: contents;"></div>

# %% [markdown]
# ### Elongation rate

# %%
p7, p8, p9 = plot_elongation_rate(ecoli_data, yeast_data, trna_data)
bokeh.io.show(p7)
bokeh.io.show(p8)
bokeh.io.show(p9)
# Out:
#   <div id="d8dfc9df-935a-4a01-8644-8c8eacaa4bff" data-root-id="p1302" style="display: contents;"></div>
#   <div id="a575cec7-7518-4ee0-8928-a3627a489022" data-root-id="p1347" style="display: contents;"></div>
#   <div id="acbf816c-ec7b-4585-be10-abcdc1c2552f" data-root-id="p1392" style="display: contents;"></div>

# %% [markdown]
# ### Watermark

# %%
# %load_ext watermark
# %watermark -v -p numpy,scipy,bokeh
# Out:
# Python implementation: CPython
# Python version       : 3.12.8
# IPython version      : 8.30.0
#
# numpy: 1.26.4
# scipy: 1.14.1
# bokeh: 3.9.1
